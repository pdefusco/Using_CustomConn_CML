# %%
# !pip3 install -r requirements.txt
# Out:
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 27.9 MB/s eta 0:00:01
# Collecting psycopg2
#   Downloading psycopg2-2.9.6.tar.gz (383 kB)
#      |████████████████████████████████| 383 kB 102.8 MB/s eta 0:00:01
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.0.33-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 98.1 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 1)) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 1)) (1.15.0)
# Collecting protobuf<=3.20.3,>=3.11.0
#   Downloading protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 107.5 MB/s eta 0:00:01
# Building wheels for collected packages: psycopg2
#   Building wheel for psycopg2 (setup.py) ... done
#   Created wheel for psycopg2: filename=psycopg2-2.9.6-cp37-cp37m-linux_x86_64.whl size=552282 sha256=6efc74c1d57bc14afd1ce207ee721a6ada33aa531c62dc5fb262dc065c7ac533
#   Stored in directory: /home/cdsw/.cache/pip/wheels/9d/f3/21/cbf320fe8a9661246db7b8e5bacc0362ec111674c8698d03ec
# Successfully built psycopg2
# Installing collected packages: protobuf, psycopg2, pandas, mysql-connector-python
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow-cml-plugin 0.0.1 requires protobuf==4.21.0, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed mysql-connector-python-8.0.33 pandas-1.3.5 protobuf-3.20.3 psycopg2-2.9.6

# %%
import os
#This password is publicly available at:
#https://rnacentral.org/help/public-database
os.environ["PG_PASS"] = "NWDMCE5xdipIjRrp"

# %%
import cml.data_v1 as cmldata

CONNECTION_NAME = "Postgres Custom Connection"

conn = cmldata.get_connection(CONNECTION_NAME)
conn.print_usage()
# Out:
# Checking Connection parameters from CML DataConnections service, fall back to ENV vars if needed
# {'PG_HOST': 'hh-pgsql-public.ebi.ac.uk', 'PG_PORT': '5432', 'PG_DB': 'pfmegrnargs', 'PG_USER': 'reader'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_221/4186975801.py in <module>
#       3 CONNECTION_NAME = "Postgres Custom Connection"
#       4
# ----> 5 conn = cmldata.get_connection(CONNECTION_NAME)
#       6 conn.print_usage()
#
# /opt/cmladdons/python/site-packages/cml/data_v1/data.py in get_connection(dataconnection_name, parameters)
#     130         dataconn_props.update(parameters)
#     131     if dataconn_props["type"] == "CUSTOM":
# --> 132         return _get_custom_connection(dataconnection_name, dataconn_props)
#     133     return ConnectionClasses[dataconn_props["type"]](dataconn_props)
#     134
#
# /opt/cmladdons/python/site-packages/cml/data_v1/data.py in _get_custom_connection(dataconnection_name, dataconn_props)
#     172     pkg = ".".join(customconnPkg)
#     173
# --> 174     return _load_custom_connection_source(pkg, custom_dataconn_props)
#     175
#     176
#
# /opt/cmladdons/python/site-packages/cml/data_v1/data.py in _load_custom_connection_source(namespace_package, parameters)
#     197                 and not cls == CustomConnection
#     198             ):
# --> 199                 return cls(parameters)
#     200     raise TypeError("No implementation of " + CustomConnection.__module__ + " found")
#     201
#
# /opt/cmladdons/python/site-packages/cml/data_v1/customconnection.py in __init__(self, properties)
#       8         """Interface to return intialize a Custom Connection object"""
#       9         self.update_properties(properties)
# ---> 10         self.override_parameters()
#      11         print("Loaded custom connection %s" % self.app_name)
#      12
#
# /dataconnections/40/861/pg-conn.py in override_parameters(self)
#     105         self.pg_user = self.check_params_or_env("PG_USER")
#     106
# --> 107         self.pg_pass = os.getenv("PG_PASS")
#
# NameError: name 'os' is not defined

# %%
SQL = "select * from rnc_database limit 5"
conn.get_pandas_dataframe(SQL)
# Out:
#    id  timestamp userstamp     descr  current_release full_descr alive for_release display_name  project_id  avg_length  min_length  max_length  num_sequences  num_organisms
# 0   5 2017-05-17    RNACEN      VEGA               98       VEGA     N        None         VEGA   PRJEB4568         NaN         NaN         NaN              0              0
# 1   1 2017-05-01    RNACEN       ENA              731        ENA     Y        None          ENA        None       412.0        10.0    900074.0       12086180         814855
# 2  26 2017-05-01    RNACEN   GENCODE              450    GENCODE     N        None      GENCODE        None       889.0        32.0    205012.0          47677              2
# 3   3 2017-05-01    RNACEN     SRPDB              732      SRPDB     Y        None        SRPDB   PRJEB4384       173.0        30.0       533.0            503            684
# 4  15 2017-05-02    RNACEN  WORMBASE              735   WormBase     Y        None     WormBase  PRJNA13758       174.0        17.0     84141.0          26116              1

# %%
import cml.data_v1 as cmldata

CONNECTION_NAME = "MySQL Custom Connection"

conn = cmldata.get_connection(CONNECTION_NAME)
conn.print_usage()
# Out:
# Checking Connection parameters from CML DataConnections service, fall back to ENV vars if needed
# {'MYSQL_HOST': 'mysql-rfam-public.ebi.ac.uk', 'MYSQL_PORT': '4497', 'MYSQL_DB': 'Rfam', 'MYSQL_USER': 'rfamro'}
# Loaded custom connection MySQL Custom Connection
#
#             Sample MYSQL CML Python Dataconnection
#             Prerequisite packages:
#             pip install mysql-connector-python
#             pip install pandas
#             Connection Parameters:
#             (These can be set in the Dataconnection defintion created by Admins or set as User Envs for the CML Session as fallback)
#               MYSQL_HOST
#               MYSQL_PORT
#               MYSQL_USER
#               MYSQL_DB
#               (A password is not required to connect to the example database)
#
#             Functions:
#               get_pandas_dataframe(query) -- Get a pandas dataframe for a specified sql query
#             --Sample Usage--
#             import cml.data_v1 as cmldata
#             CONNECTION_NAME = "MySQL Custom Connection"
#             conn = cmldata.get_connection(CONNECTION_NAME)
#             results = pd.get

# %%
mySql_Query = """SELECT fr.rfam_acc, fr.rfamseq_acc, fr.seq_start, fr.seq_end
                                FROM full_region fr, rfamseq rf, taxonomy tx
                                WHERE rf.ncbi_id = tx.ncbi_id
                                AND fr.rfamseq_acc = rf.rfamseq_acc
                                AND tx.ncbi_id = 10116 -- NCBI taxonomy id of Rattus norvegicus
                                AND is_significant = 1 -- exclude low-scoring matches from the same clan
                                LIMIT 0,10"""
conn.get_pandas_dataframe(mySql_Query)
# Out:
#   rfam_acc     rfamseq_acc  seq_start  seq_end
# 0  RF02143  AABR05000762.1       4020     3788
# 1  RF02151  AABR05005289.1       3544     3451
# 2  RF00604  AABR05007302.1     150415   150504
# 3  RF00133  AABR05007347.1      14415    14333
# 4  RF00108  AABR05008878.1       9310     9218
# 5  RF02116  AABR05016229.1       5765     5923
# 6  RF00457  AABR05020750.1      57609    57810
# 7  RF00598  AABR05022670.1      19047    19179
# 8  RF00286  AABR05027791.1      11759    11629
# 9  RF01877  AABR05033787.1      16536    16915
